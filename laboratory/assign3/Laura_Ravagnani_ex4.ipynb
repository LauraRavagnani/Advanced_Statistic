# %%
# select a random box (from 0 to 5)
j <- floor(runif(1, 0, 6))

n_trial <- 100
trial <- 0:n_trial

# outcome
outcome <- rbinom(n_trial, 1, j/5)  # 1 = white, 0 = black
E <- c("-", outcome)

cat(paste("Box selected:", "H", j, '\n'))
# Out:
# Box selected: H 2

# %%
H0 <- rep(0.167, length(trial))
H1 <- rep(0.167, length(trial))
H2 <- rep(0.167, length(trial))
H3 <- rep(0.167, length(trial))
H4 <- rep(0.167, length(trial))
H5 <- rep(0.167, length(trial))

sum <- rep(0, length(trial))

# %%
# upgrade the probability of every box at each trial
for (i in 2:length(trial)) {

    if(E[i] == 1){
        sum[i-1] <- 1/5 * H1[i-1] + 2/5 * H2[i-1] + 3/5 * H3[i-1] + 4/5 * H4[i-1] + H5[i-1]

        H0[i] <- 0
        H1[i] <- 1/5 * H1[i-1] / sum[i-1]
        H2[i] <- 2/5 * H2[i-1] / sum[i-1]
        H3[i] <- 3/5 * H3[i-1] / sum[i-1]
        H4[i] <- 4/5 * H4[i-1] / sum[i-1]
        H5[i] <- 5/5 * H5[i-1] / sum[i-1]
    }
    else{
        sum[i-1] <- H0[i-1] + 4/5 * H1[i-1] + 3/5 * H2[i-1] + 2/5 * H3[i-1] + 1/5 * H4[i-1]

        H0[i] <- 5/5 * H0[i-1] / sum[i-1]
        H1[i] <- 4/5 * H1[i-1] / sum[i-1]
        H2[i] <- 3/5 * H2[i-1] / sum[i-1]
        H3[i] <- 2/5 * H3[i-1] / sum[i-1]
        H4[i] <- 1/5 * H4[i-1] / sum[i-1]
        H5[i] <- 0
    }
}

# %%
# plots
plot(trial, H0, type = "p", pch = 19, col = "red", ylab = "probability", main = "H0", ylim = c(0,1))
plot(trial, H1, type = "p", pch = 19, col = "orange", ylab = "probability", main = "H1", ylim = c(0,1))
plot(trial, H2, type = "p", pch = 19, col = "yellow2", ylab = "probability", main = "H2", ylim = c(0,1))
plot(trial, H3, type = "p", pch = 19, col = "green3", ylab = "probability", main = "H3", ylim = c(0,1))
plot(trial, H4, type = "p", pch = 19, col = "blue", ylab = "probability", main = "H4", ylim = c(0,1))
plot(trial, H5, type = "p", pch = 19, col = "purple", ylab = "probability", main = "H5", ylim = c(0,1))
# Out:
# Plot with title “H0”
# Plot with title “H1”
# Plot with title “H2”
# Plot with title “H3”
# Plot with title “H4”
# Plot with title “H5”

# %%
df <- data.frame(trial, E, H0, H1, H2, H3, H4, H5)
head(df, 20)
# Out:
#    trial E H0    H1         H2         H3        H4           H5
# 1   0    - 0.167 0.16700000 0.16700000 0.1670000 0.1670000000 0.1670000
# 2   1    1 0.000 0.06666667 0.13333333 0.2000000 0.2666666667 0.3333333
# 3   2    1 0.000 0.01818182 0.07272727 0.1636364 0.2909090909 0.4545455
# 4   3    0 0.000 0.08000000 0.24000000 0.3600000 0.3200000000 0.0000000
# 5   4    1 0.000 0.02739726 0.16438356 0.3698630 0.4383561644 0.0000000
# 6   5    0 0.000 0.06153846 0.27692308 0.4153846 0.2461538462 0.0000000
# 7   6    0 0.000 0.11428571 0.38571429 0.3857143 0.1142857143 0.0000000
# 8   7    0 0.000 0.18285714 0.46285714 0.3085714 0.0457142857 0.0000000
# 9   8    1 0.000 0.08247423 0.41752577 0.4175258 0.0824742268 0.0000000
# 10  9    0 0.000 0.13195876 0.50103093 0.3340206 0.0329896907 0.0000000
# 11 10    1 0.000 0.05818182 0.44181818 0.4418182 0.0581818182 0.0000000
# 12 11    0 0.000 0.09309091 0.53018182 0.3534545 0.0232727273 0.0000000
# 13 12    1 0.000 0.04035309 0.45964691 0.4596469 0.0403530895 0.0000000
# 14 13    0 0.000 0.06456494 0.55157629 0.3677175 0.0161412358 0.0000000
# 15 14    0 0.000 0.09692381 0.62101278 0.2760057 0.0060577378 0.0000000
# 16 15    0 0.000 0.13802864 0.66328559 0.1965291 0.0021566976 0.0000000
# 17 16    1 0.000 0.06691280 0.64308818 0.2858170 0.0041820499 0.0000000
# 18 17    0 0.000 0.09652978 0.69579921 0.2061627 0.0015082779 0.0000000
# 19 18    0 0.000 0.13372783 0.72294570 0.1428041 0.0005223744 0.0000000
# 20 19    1 0.000 0.06652726 0.71930565 0.2131276 0.0010394884 0.0000000
